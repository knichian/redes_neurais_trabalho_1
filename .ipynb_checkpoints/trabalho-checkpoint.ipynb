# %% [markdown]
# ---
# ### Importando-Pacotes
# ---

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ---
# ### Importando-Dataframe:
# ---

# %%
df = pd.read_csv("dataset/breast-cancer.csv")

# %% [markdown]
# ---
# ### Tratamento-de-Dados:
# ---

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# ---
# ### Encoding
# ---

# %%
le = LabelEncoder()

df_num = df.copy(deep=True)

for i in df_num.columns:
  if df_num[i].dtype == 'object': 
    df_num[i] = le.fit_transform(df_num[i].astype(str))
    print(df_num[i].dtype)
# Out:
# int64

# %%
display(df_num['diagnosis'])
# display(df['diagnosis'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %% [markdown]
# ---
# ### Histogramas-Dataframe:
# ---

# %%
df_sem_id = df.iloc[:, 1:]  # ignora a primeira coluna (índice 0)

for coluna in df_sem_id.select_dtypes(include=['number']).columns:
    plt.figure(figsize=(6, 4))
    plt.hist(df_sem_id[coluna].dropna(), bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Histograma da coluna: {coluna}')
    plt.xlabel(coluna)
    plt.ylabel('Frequência')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---
# ### Matriz-de-Correlação:
# ---

# %%
corr = df.corr(numeric_only=True)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7e126_row0_col0, #T_7e126_row1_col1, #T_7e126_row1_col3, #T_7e126_row2_col2, #T_7e126_row3_col1, #T_7e126_row3_col3, #T_7e126_row4_col4, #T_7e126_row5_col5, #T_7e126_row6_col6, #T_7e126_row7_col7, #T_7e126_row8_col8, #T_7e126_row9_col9, #T_7e126_row10_col10, #T_7e126_row11_col11, #T_7e126_row12_col12, #T_7e126_row13_col13, #T_7e126_row14_col14, #T_7e126_row15_col15, #T_7e126_row16_col16, #T_7e126_row17_col17, #T_7e126_row18_col18, #T_7e126_row19_col19, #T_7e126_row20_col20, #T_7e126_row21_col21, #T_7e126_row22_col22, #T_7e126_row23_col23, #T_7e126_row24_col24, #T_7e126_row25_col25, #T_7e126_row26_col26, #T_7e126_row27_col27, #T_7e126_row28_col28, #T_7e126_row29_col29, #T_7e126_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7e126_row0_col1, #T_7e126_row0_col4, #T_7e126_row5_col16, #T_7e126_row11_col17 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7e126_row0_col2, #T_7e126_row2_col16, #T_7e126_row4_col17, #T_7e126_row12_col1, #T_7e126_row14_col20 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_7e126_row0_col3, #T_7e126_row10_col28, #T_7e126_row14_col5, #T_7e126_row17_col5, #T_7e126_row22_col7, #T_7e126_row22_col14, #T_7e126_row24_col25 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_7e126_row0_col5, #T_7e126_row10_col23, #T_7e126_row15_col27, #T_7e126_row22_col18, #T_7e126_row23_col15, #T_7e126_row29_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_7e126_row0_
col10 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_7e126_row1_col4, #T_7e126_row3_col4, #T_7e126_row4_col1, #T_7e126_row4_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col5, #T_7e126_row12_col13, #T_7e126_row13_col25 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col6, #T_7e126_row10_col26, #T_7e126_row20_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_7e126_row1_col7, #T_7e126_row5_col6, #T_7e126_row7_col16, #T_7e126_row24_col7, #T_7e126_row26_col8, #T_7e126_row26_col29 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_7e126_row1_col8, #T_7e126_row4_col8, #T_7e126_row4_col14, #T_7e126_row5_col25, #T_7e126_row26_col30, #T_7e126_row28_col3, #T_7e126_row28_col26 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col9, #T_7e126_row12_col18, #T_7e126_row15_col11, #T_7e126_row17_col22, #T_7e126_row19_col4, #T_7e126_row22_col13, #T_7e126_row26_col19 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col11 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_7e126_row1_col12, #T_7e126_row9_col0, #T_7e126_row12_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col13, #T_7e126_row6_col23, #T_7e126_row16_col27, #T_7e126_row27_col21 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_7e126_row1_col14, #T_7e126_row7_col4, #T_7e126_row11_col1, #T_7e126_row11_col3, #T_7e126_row13_col3 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_7e126_row1_col15, #T_7e126_row15_col8, #T_7e126_row21_col20, #T_7e126_row28_col12 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col16, #T_7e126_row2_col10, #T_7e126_row14_col29, #T_7e126_row20_col23, #T_7e126_row21_col16, #T_7e126_row23_col30 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col17, #T_7e126_row2_col0, #T_7e126_row12_col9, #T_7e126_row12_col17, #T_7e126_row25_col18, #T_7e126_row27_col19, #T_7e126_row29_col20 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col18, #T_7e126_row2_col14, #T_7e126_row11_col15 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_7e126_row1_col21, #T_7e126_row3_col21, #T_7e126_row3_col23, #T_7e126_row13_col11, #T_7e126_row21_col3, #T_7e126_row23_col1, #T_7e126_row23_col3 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col22, #T_7e126_row2_col27, #T_7e126_row11_col26, #T_7e126_row14_col26, #T_7e126_row15_col5, #T_7e126_row16_col14, #T_7e126_row20_col9, #T_7e126_row28_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_7e126_row1_col23, #T_7e126_row4_col21, #T_7e126_row11_col13, #T_7e126_row21_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col24, #T_7e126_row3_col24, #T_7e126_row14_col11 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col25, #T_7e126_row3_col17, #T_7e126_row7_col12, #T_7e126_row13_col0, #T_7e126_row23_col17, #T_7e126_row30_col2, #T_7e126_row30_col19 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_7e126_row1_col26, #T_7e126_row5_col29, #T_7e126_row9_col30, #T_7e126_row16_col15, #T_7e126_row16_col19, #T_7e126_row17_col30, #T_7e126_row18_col14, #T_7e126_row19_col9, #T_7e126_row22_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_7e126_row1_col27,

# %%
sns.heatmap(df_num.corr(), annot=False, cbar=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# ---
# ### Boxplot-Dataframe:
# ---

# %%
# sns.boxplot(data=df, x='diagnosis', y=) # selecionar o que tem a melhor correlação com o atributo "diagnosis" na matriz de correlação para o Y
# plt.show()
